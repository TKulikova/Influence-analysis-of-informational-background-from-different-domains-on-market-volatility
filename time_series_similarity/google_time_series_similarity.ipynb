# %%
import warnings
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")
import pandas as pd
pd.options.display.max_colwidth = 100
pd.options.display.max_rows = 2000
plt.style.use('seaborn-whitegrid')

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd 
analyst_update_dataset = pd.read_csv("gdrive/My Drive/analyst_update_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
analyst_update_dataset = analyst_update_dataset.replace(replaces)
analyst_update_dataset['Release date']  = pd.to_datetime(pd.to_datetime(analyst_update_dataset['Release date']).dt.date)

# %%
general_news_dataset = pd.read_csv("gdrive/My Drive/general_news_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
general_news_dataset = general_news_dataset.replace(replaces)
general_news_dataset['Release date']  = pd.to_datetime(pd.to_datetime(general_news_dataset['Release date']).dt.date)

# %%
central_banks_dataset = pd.read_csv("gdrive/My Drive/central_banks_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
central_banks_dataset = central_banks_dataset.replace(replaces)
central_banks_dataset['Release date']  = pd.to_datetime(pd.to_datetime(central_banks_dataset['Release date']).dt.date)

# %%
currencies_dataset = pd.read_csv("gdrive/My Drive/currencies_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
currencies_dataset = currencies_dataset.replace(replaces)
currencies_dataset['Release date']  = pd.to_datetime(pd.to_datetime(currencies_dataset['Release date']).dt.date)

# %%
dividend_dataset = pd.read_csv("gdrive/My Drive/dividend_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
dividend_dataset = dividend_dataset.replace(replaces)
dividend_dataset['Release date']  = pd.to_datetime(pd.to_datetime(dividend_dataset['Release date']).dt.date)

# %%
earnings_dataset = pd.read_csv("gdrive/My Drive/earnings_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
earnings_dataset = earnings_dataset.replace(replaces)
earnings_dataset['Release date']  = pd.to_datetime(pd.to_datetime(earnings_dataset['Release date']).dt.date)

# %%
energy_oil_dataset = pd.read_csv("gdrive/My Drive/energy_oil_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
energy_oil_dataset = energy_oil_dataset.replace(replaces)
energy_oil_dataset['Release date']  = pd.to_datetime(pd.to_datetime(energy_oil_dataset['Release date']).dt.date)

# %%
financials_dataset = pd.read_csv("gdrive/My Drive/financials_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
financials_dataset = financials_dataset.replace(replaces)
financials_dataset['Release date']  = pd.to_datetime(pd.to_datetime(financials_dataset['Release date']).dt.date)

# %%
gold_metals_dataset = pd.read_csv("gdrive/My Drive/gold_metals_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
gold_metals_dataset = gold_metals_dataset.replace(replaces)
gold_metals_dataset['Release date']  = pd.to_datetime(pd.to_datetime(gold_metals_dataset['Release date']).dt.date)

# %%
investments_dataset = pd.read_csv("gdrive/My Drive/investments_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
investments_dataset = investments_dataset.replace(replaces)
investments_dataset['Release date']  = pd.to_datetime(pd.to_datetime(investments_dataset['Release date']).dt.date)

# %%
ipo_dataset = pd.read_csv("gdrive/My Drive/ipo_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
ipo_dataset = ipo_dataset.replace(replaces)
ipo_dataset['Release date']  = pd.to_datetime(pd.to_datetime(ipo_dataset['Release date']).dt.date)

# %%
legal_dataset = pd.read_csv("gdrive/My Drive/legal_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
legal_dataset = legal_dataset.replace(replaces)
legal_dataset['Release date']  = pd.to_datetime(pd.to_datetime(legal_dataset['Release date']).dt.date)

# %%
macro_dataset = pd.read_csv("gdrive/My Drive/macro_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
macro_dataset = macro_dataset.replace(replaces)
macro_dataset['Release date']  = pd.to_datetime(pd.to_datetime(macro_dataset['Release date']).dt.date)

# %%
markets_dataset = pd.read_csv("gdrive/My Drive/markets_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
markets_dataset = markets_dataset.replace(replaces)
markets_dataset['Release date']  = pd.to_datetime(pd.to_datetime(markets_dataset['Release date']).dt.date)

# %%
personnel_change_dataset = pd.read_csv("gdrive/My Drive/personnel_change_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
personnel_change_dataset = personnel_change_dataset.replace(replaces)
personnel_change_dataset['Release date']  = pd.to_datetime(pd.to_datetime(personnel_change_dataset['Release date']).dt.date)

# %%
politics_dataset = pd.read_csv("gdrive/My Drive/politics_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
politics_dataset = politics_dataset.replace(replaces)
politics_dataset['Release date']  = pd.to_datetime(pd.to_datetime(politics_dataset['Release date']).dt.date)

# %%
product_news_dataset = pd.read_csv("gdrive/My Drive/product_news_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
product_news_dataset = product_news_dataset.replace(replaces)
product_news_dataset['Release date']  = pd.to_datetime(pd.to_datetime(product_news_dataset['Release date']).dt.date)

# %%
stock_commentary_dataset = pd.read_csv("gdrive/My Drive/stock_commentary_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
stock_commentary_dataset = stock_commentary_dataset.replace(replaces)
stock_commentary_dataset['Release date']  = pd.to_datetime(pd.to_datetime(stock_commentary_dataset['Release date']).dt.date)

# %%
stock_movement_dataset = pd.read_csv("gdrive/My Drive/stock_movement_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
stock_movement_dataset = stock_movement_dataset.replace(replaces)
stock_movement_dataset['Release date']  = pd.to_datetime(pd.to_datetime(stock_movement_dataset['Release date']).dt.date)

# %%
treasuries_dataset = pd.read_csv("gdrive/My Drive/treasuries_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
treasuries_dataset = treasuries_dataset.replace(replaces)
treasuries_dataset['Release date']  = pd.to_datetime(pd.to_datetime(treasuries_dataset['Release date']).dt.date)

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install dtaidistance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 51.6 MB/s eta 0:00:00
# ...

# %%
def relation_count(series):
  if 3 not in series.value_counts().index.tolist():
    pos_count = 0
  else:
    pos_count = series.value_counts()[3]
  if 2 not in series.value_counts().index.tolist():
    neutral_count = 0
  else:
    neutral_count = series.value_counts()[2]
  if series.shape[0] == 0:
    return 0
  if series.shape[0] == neutral_count:
    return 0
  return pos_count/(series.shape[0] - neutral_count)

# %%
from matplotlib import style
from scipy.signal import savgol_filter
plt.figure(figsize=(25,5))

google_analyst_update = analyst_update_dataset[analyst_update_dataset.Ticker == 'GOOGL']
grouped = google_analyst_update.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(200.5).mean()
heights = np.array(heights)
sentiments = heights[0:]


import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Analyst Update news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2012-10-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
dates = list(grouped_history.groups.keys())
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
plt.plot(datetimes, sentiments, label='Sentiments (Analyst Update)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('analyst_update_graph.png')

# %%
import scipy.stats as sp
from dtaidistance import dtw
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.11626823723821718
# Spearman 0.41421518556350023
# Kendall's tau 0.3283963227783453
# DTW 4.851448342902095

# %%
plt.figure(figsize=(25,5))

google_general_news = general_news_dataset[general_news_dataset.Ticker == 'GOOGL']
grouped = google_general_news.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(100.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive General news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2012-08-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (General news)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8782351836340716
# Spearman 0.9416525965632546
# Kendall's tau 0.7895386108418551
# DTW 1.2464712908760678

# %%
plt.figure(figsize=(25,5))

google_central_banks = central_banks_dataset[central_banks_dataset.Ticker == 'GOOGL']
grouped = google_central_banks.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Fed | Central banks ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2013-10-01", end='2019-10-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Fed | Central banks)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.26850979251342216
# Spearman 0.4711305227496611
# Kendall's tau 0.13168957938133138
# DTW 2.8925732794493073

# %%
plt.figure(figsize=(25,5))

google_currencies = currencies_dataset[currencies_dataset.Ticker == 'GOOGL']
grouped = google_currencies.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Currencies ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2009-10-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Currencies)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.04962183662319851
# Spearman 0.022180959874114867
# Kendall's tau -0.17256753212693415
# DTW 5.529114001307259

# %%
plt.figure(figsize=(25,5))

google_dividend = dividend_dataset[dividend_dataset.Ticker == 'GOOGL']
grouped = google_dividend.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Dividend ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2013-12-01", end='2018-07-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)

dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Dividend)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson nan
# Spearman nan
# Kendall's tau nan
# DTW 5.699055775778177

# %%
plt.figure(figsize=(25,5))

google_earnings = earnings_dataset[earnings_dataset.Ticker == 'GOOGL']
grouped = google_earnings.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Earnings ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2011-07-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Earnings)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('earnings_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.27617474795448704
# Spearman 0.3350377014780441
# Kendall's tau 0.20259546349149057
# DTW 4.075431155583974

# %%
plt.figure(figsize=(25,5))

google_energy_oil = energy_oil_dataset[energy_oil_dataset.Ticker == 'GOOGL']
grouped = google_energy_oil.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Energy | Oil news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2011-03-01", end='2019-12-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Energy | Oil)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson -0.3302390657850869
# Spearman -0.34478259007739714
# Kendall's tau -0.3044298691416411
# DTW 5.63240638001216

# %%
plt.figure(figsize=(25,5))
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

google_financials = financials_dataset[financials_dataset.Ticker == 'GOOGL']
grouped = google_financials.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Financials news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2011-04-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Financials)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('financials_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.7300429174152854
# Spearman 0.784272810987676
# Kendall's tau 0.6624933874096279
# DTW 2.5337923759414602

# %%
plt.figure(figsize=(25,5))

google_gold_metals = gold_metals_dataset[gold_metals_dataset.Ticker == 'GOOGL']
grouped = google_gold_metals.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
heights = savgol_filter(heights, 49, 2)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Gold | Metals | Materials news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2011-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Gold | Metals | Materials)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson -0.27767670855005927
# Spearman 0.07237622457496815
# Kendall's tau 0.2164477441462022
# DTW 4.373749653619926

# %%
plt.figure(figsize=(25,5))

google_investments = investments_dataset[investments_dataset.Ticker == 'GOOGL']
grouped = google_investments.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Investments news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2009-08-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Investments)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.9574013882720602
# Spearman 0.9056718024023398
# Kendall's tau 0.7741036903247873
# DTW 1.9881619850963492

# %%
plt.figure(figsize=(25,5))

google_ipo = ipo_dataset[ipo_dataset.Ticker == 'GOOGL']
grouped = google_ipo.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive IPO news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2012-05-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (IPO)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('ipo_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8818973275480217
# Spearman 0.8613108798135127
# Kendall's tau 0.6390757535225376
# DTW 2.2024965365794524

# %%
plt.figure(figsize=(25,5))

google_legal = legal_dataset[legal_dataset.Ticker == 'GOOGL']
grouped = google_legal.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Legal | Regulation news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2009-09-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Legal | Regulation)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('legal_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8738395147561858
# Spearman 0.8705164220254968
# Kendall's tau 0.6581504050681481
# DTW 2.153765493228903

# %%
plt.figure(figsize=(25,5))

google_macro = macro_dataset[macro_dataset.Ticker == 'GOOGL']
grouped = google_macro.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Macro news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2012-04-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Macro)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.9606330882609662
# Spearman 0.966202311741632
# Kendall's tau 0.8232136703922612
# DTW 1.3293299428112892

# %%
plt.figure(figsize=(25,5))

google_markets = markets_dataset[markets_dataset.Ticker == 'GOOGL']
grouped = google_markets.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]


import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Markets news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2009-07-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Markets)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.9685519071917028
# Spearman 0.9340150613440761
# Kendall's tau 0.8075787401574804
# DTW 0.7322474596615723

# %%
plt.figure(figsize=(25,5))

google_personnel_change = personnel_change_dataset[personnel_change_dataset.Ticker == 'GOOGL']
grouped = google_personnel_change.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Personnel Change news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2014-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Personnel Change)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson -0.47400571339327624
# Spearman -0.9700791172874583
# Kendall's tau -0.905677471709801
# DTW 5.622256621360146

# %%
plt.figure(figsize=(25,5))

google_politics = politics_dataset[politics_dataset.Ticker == 'GOOGL']
grouped = google_politics.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]


import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Politics news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2014-11-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Politics)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.7903289480499547
# Spearman 0.7443417640491996
# Kendall's tau 0.5370305467025667
# DTW 1.6665781669471433

# %%
plt.figure(figsize=(30,10))

google_product_news = product_news_dataset[product_news_dataset.Ticker == 'GOOGL']
grouped = google_product_news.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Company | Product news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2009-04-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Positive news ratio')
plt.plot(dates, mean_prices, label = 'Prices')
plt.title('Monthly Google stock prices and Product positive news ratio', fontsize = 25)
plt.xlabel('Date', fontsize = 25)
plt.ylabel('Positive news ratio / Prices', fontsize = 25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.savefig('google_product_news_prices_sentiments.pdf')
# Out:
# [Timestamp('2009-04-30 00:00:00', freq='M'), Timestamp('2009-05-31 00:00:00', freq='M'), Timestamp('2009-06-30 00:00:00', freq='M'), Timestamp('2009-07-31 00:00:00', freq='M'), Timestamp('2009-08-31 00:00:00', freq='M'), Timestamp('2009-09-30 00:00:00', freq='M'), Timestamp('2009-10-31 00:00:00', freq='M'), Timestamp('2009-11-30 00:00:00', freq='M'), Timestamp('2009-12-31 00:00:00', freq='M'), Timestamp('2010-01-31 00:00:00', freq='M'), Timestamp('2010-02-28 00:00:00', freq='M'), Timestamp('2010-03-31 00:00:00', freq='M'), Timestamp('2010-04-30 00:00:00', freq='M'), Timestamp('2010-05-31 00:00:00', freq='M'), Timestamp('2010-06-30 00:00:00', freq='M'), Timestamp('2010-07-31 00:00:00', freq='M'), Timestamp('2010-08-31 00:00:00', freq='M'), Timestamp('2010-09-30 00:00:00', freq='M'), Timestamp('2010-10-31 00:00:00', freq='M'), Timestamp('2010-11-30 00:00:00', freq='M'), Timestamp('2010-12-31 00:00:00', freq='M'), Timestamp('2011-01-31 00:00:00', freq='M'), Timestamp('2011-02-28 00:00:0
# ...

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.9526203457151591
# Spearman 0.9747691539324868
# Kendall's tau 0.8863139301336889
# DTW 1.2544112844554587

# %%
plt.figure(figsize=(30,10))

google_stock_commentary = stock_commentary_dataset[stock_commentary_dataset.Ticker == 'GOOGL']
grouped = google_stock_commentary.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Stock Commentary news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2012-03-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Stock Commentary)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('stock_commentary_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8311889187323275
# Spearman 0.8578037054257545
# Kendall's tau 0.7055986687882829
# DTW 1.0068896887463425

# %%
plt.figure(figsize=(30,10))

google_stock_movement = stock_movement_dataset[stock_movement_dataset.Ticker == 'GOOGL']
grouped = google_stock_movement.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Stock Movement news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2011-04-01", end='2020-02-29')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Stock Movement)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.904907680294502
# Spearman 0.9401632607997319
# Kendall's tau 0.8098044202807928
# DTW 1.1587644362982248

# %%
plt.figure(figsize=(30,10))

google_treasuries = treasuries_dataset[treasuries_dataset.Ticker == 'GOOGL']
grouped = google_treasuries.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
google_history = yahooFinance.Ticker("GOOGL")
plt.title('Monthly Google historical stock prices and monthly positive Treasuries news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = google_history.history(start="2011-07-01", end='2019-07-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Treasuries)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8552362967418001
# Spearman 0.8313759126717184
# Kendall's tau 0.597433354751735
# DTW 2.813073648249266
