# %%
import warnings
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")
import pandas as pd
pd.options.display.max_colwidth = 100
pd.options.display.max_rows = 2000
plt.style.use('seaborn-whitegrid')

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd 
analyst_update_dataset = pd.read_csv("gdrive/My Drive/analyst_update_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
analyst_update_dataset = analyst_update_dataset.replace(replaces)
analyst_update_dataset['Release date']  = pd.to_datetime(pd.to_datetime(analyst_update_dataset['Release date']).dt.date)

# %%
general_news_dataset = pd.read_csv("gdrive/My Drive/general_news_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
general_news_dataset = general_news_dataset.replace(replaces)
general_news_dataset['Release date']  = pd.to_datetime(pd.to_datetime(general_news_dataset['Release date']).dt.date)

# %%
central_banks_dataset = pd.read_csv("gdrive/My Drive/central_banks_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
central_banks_dataset = central_banks_dataset.replace(replaces)
central_banks_dataset['Release date']  = pd.to_datetime(pd.to_datetime(central_banks_dataset['Release date']).dt.date)

# %%
currencies_dataset = pd.read_csv("gdrive/My Drive/currencies_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
currencies_dataset = currencies_dataset.replace(replaces)
currencies_dataset['Release date']  = pd.to_datetime(pd.to_datetime(currencies_dataset['Release date']).dt.date)

# %%
dividend_dataset = pd.read_csv("gdrive/My Drive/dividend_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
dividend_dataset = dividend_dataset.replace(replaces)
dividend_dataset['Release date']  = pd.to_datetime(pd.to_datetime(dividend_dataset['Release date']).dt.date)

# %%
earnings_dataset = pd.read_csv("gdrive/My Drive/earnings_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
earnings_dataset = earnings_dataset.replace(replaces)
earnings_dataset['Release date']  = pd.to_datetime(pd.to_datetime(earnings_dataset['Release date']).dt.date)

# %%
energy_oil_dataset = pd.read_csv("gdrive/My Drive/energy_oil_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
energy_oil_dataset = energy_oil_dataset.replace(replaces)
energy_oil_dataset['Release date']  = pd.to_datetime(pd.to_datetime(energy_oil_dataset['Release date']).dt.date)

# %%
financials_dataset = pd.read_csv("gdrive/My Drive/financials_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
financials_dataset = financials_dataset.replace(replaces)
financials_dataset['Release date']  = pd.to_datetime(pd.to_datetime(financials_dataset['Release date']).dt.date)

# %%
gold_metals_dataset = pd.read_csv("gdrive/My Drive/gold_metals_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
gold_metals_dataset = gold_metals_dataset.replace(replaces)
gold_metals_dataset['Release date']  = pd.to_datetime(pd.to_datetime(gold_metals_dataset['Release date']).dt.date)

# %%
investments_dataset = pd.read_csv("gdrive/My Drive/investments_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
investments_dataset = investments_dataset.replace(replaces)
investments_dataset['Release date']  = pd.to_datetime(pd.to_datetime(investments_dataset['Release date']).dt.date)

# %%
ipo_dataset = pd.read_csv("gdrive/My Drive/ipo_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
ipo_dataset = ipo_dataset.replace(replaces)
ipo_dataset['Release date']  = pd.to_datetime(pd.to_datetime(ipo_dataset['Release date']).dt.date)

# %%
legal_dataset = pd.read_csv("gdrive/My Drive/legal_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
legal_dataset = legal_dataset.replace(replaces)
legal_dataset['Release date']  = pd.to_datetime(pd.to_datetime(legal_dataset['Release date']).dt.date)

# %%
macro_dataset = pd.read_csv("gdrive/My Drive/macro_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
macro_dataset = macro_dataset.replace(replaces)
macro_dataset['Release date']  = pd.to_datetime(pd.to_datetime(macro_dataset['Release date']).dt.date)

# %%
markets_dataset = pd.read_csv("gdrive/My Drive/markets_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
markets_dataset = markets_dataset.replace(replaces)
markets_dataset['Release date']  = pd.to_datetime(pd.to_datetime(markets_dataset['Release date']).dt.date)

# %%
personnel_change_dataset = pd.read_csv("gdrive/My Drive/personnel_change_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
personnel_change_dataset = personnel_change_dataset.replace(replaces)
personnel_change_dataset['Release date']  = pd.to_datetime(pd.to_datetime(personnel_change_dataset['Release date']).dt.date)

# %%
politics_dataset = pd.read_csv("gdrive/My Drive/politics_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
politics_dataset = politics_dataset.replace(replaces)
politics_dataset['Release date']  = pd.to_datetime(pd.to_datetime(politics_dataset['Release date']).dt.date)

# %%
product_news_dataset = pd.read_csv("gdrive/My Drive/product_news_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
product_news_dataset = product_news_dataset.replace(replaces)
product_news_dataset['Release date']  = pd.to_datetime(pd.to_datetime(product_news_dataset['Release date']).dt.date)

# %%
stock_commentary_dataset = pd.read_csv("gdrive/My Drive/stock_commentary_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
stock_commentary_dataset = stock_commentary_dataset.replace(replaces)
stock_commentary_dataset['Release date']  = pd.to_datetime(pd.to_datetime(stock_commentary_dataset['Release date']).dt.date)

# %%
stock_movement_dataset = pd.read_csv("gdrive/My Drive/stock_movement_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
stock_movement_dataset = stock_movement_dataset.replace(replaces)
stock_movement_dataset['Release date']  = pd.to_datetime(pd.to_datetime(stock_movement_dataset['Release date']).dt.date)

# %%
treasuries_dataset = pd.read_csv("gdrive/My Drive/treasuries_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
treasuries_dataset = treasuries_dataset.replace(replaces)
treasuries_dataset['Release date']  = pd.to_datetime(pd.to_datetime(treasuries_dataset['Release date']).dt.date)

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/dist-packages (0.2.14)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.3.6)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from yfinance) (40.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
# !pip install dtaidistance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dtaidistance
#   Downloading dtaidistance-2.3.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from dtaidistance) (1.22.4)
# Installing collected packages: dtaidistance
# Successfully installed dtaidistance-2.3.10

# %%
def relation_count(series):
  if 3 not in series.value_counts().index.tolist():
    pos_count = 0
  else:
    pos_count = series.value_counts()[3]
  if 2 not in series.value_counts().index.tolist():
    neutral_count = 0
  else:
    neutral_count = series.value_counts()[2]
  if series.shape[0] == 0:
    return 0
  if series.shape[0] == neutral_count:
    return 0
  return pos_count/(series.shape[0] - neutral_count)

# %%
from matplotlib import style
from scipy.signal import savgol_filter
plt.figure(figsize=(25,5))

tesla_analyst_update = analyst_update_dataset[analyst_update_dataset.Ticker == 'TSLA']
grouped = tesla_analyst_update.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(200.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Analyst Update news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2013-05-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
dates = list(grouped_history.groups.keys())
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
plt.plot(datetimes, sentiments, label='Sentiments (Analyst Update)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('analyst_update_graph.png')

# %%
from dtaidistance import dtw
import scipy.stats as sp

print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8692260631827966
# Spearman 0.8851143499822003
# Kendall's tau 0.7119604415431845
# DTW 1.5145711436788507

# %%
plt.figure(figsize=(25,5))

tesla_general_news = general_news_dataset[general_news_dataset.Ticker == 'TSLA']
grouped = tesla_general_news.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(100.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive General news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2012-05-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (General news | Opinion)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.6161032423697952
# Spearman 0.549304449632777
# Kendall's tau 0.4014120340452604
# DTW 1.333942879800668

# %%
plt.figure(figsize=(25,5))

tesla_central_banks = central_banks_dataset[central_banks_dataset.Ticker == 'TSLA']
grouped = tesla_central_banks.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]


import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Fed | Central banks ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2014-04-01", end='2019-07-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Fed | Central banks)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson -0.3907082643659645
# Spearman -0.4262362637362637
# Kendall's tau -0.308531746031746
# DTW 6.489280230706358

# %%
plt.figure(figsize=(25,5))

tesla_currencies = currencies_dataset[currencies_dataset.Ticker == 'TSLA']
grouped = tesla_currencies.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Currencies ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2015-02-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Currencies)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.619893512100255
# Spearman 0.5810508475964643
# Kendall's tau 0.3802236101592536
# DTW 2.9250164241321874

# %%
plt.figure(figsize=(25,5))

tesla_dividend = dividend_dataset[dividend_dataset.Ticker == 'TSLA']
grouped = tesla_dividend.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Dividend ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2018-04-01", end='2019-03-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Dividend)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.45360143435903916
# Spearman 0.614989552184821
# Kendall's tau 0.5393598899705936
# DTW 2.7681440573893714

# %%
plt.figure(figsize=(25,5))

tesla_earnings = earnings_dataset[earnings_dataset.Ticker == 'TSLA']
grouped = tesla_earnings.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Earnings ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2013-02-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Earnings)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('earnings_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.6197367709541692
# Spearman 0.7242665859003798
# Kendall's tau 0.5080368230884017
# DTW 1.0878438694984347

# %%
plt.figure(figsize=(25,5))

tesla_energy_oil = energy_oil_dataset[energy_oil_dataset.Ticker == 'TSLA']
grouped = tesla_energy_oil.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Energy | Oil news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2013-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Energy | Oil)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.6305006916113687
# Spearman 0.5004687551581691
# Kendall's tau 0.33472342193267757
# DTW 2.9206852424249465

# %%
plt.figure(figsize=(25,5))
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

tesla_financials = financials_dataset[financials_dataset.Ticker == 'TSLA']
grouped = tesla_financials.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Financials news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2014-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Financials)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('financials_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.7506727046713243
# Spearman 0.6948044862796198
# Kendall's tau 0.4629677393276931
# DTW 2.827203812795733

# %%
plt.figure(figsize=(25,5))

tesla_gold_metals = gold_metals_dataset[gold_metals_dataset.Ticker == 'TSLA']
grouped = tesla_gold_metals.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
heights = savgol_filter(heights, 49, 2)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Gold | Metals | Materials news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2014-04-01", end='2019-11-30')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Gold | Metals | Materials)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.475636937802098
# Spearman 0.34862770546245747
# Kendall's tau 0.18437225636523263
# DTW 3.5457054952098166

# %%
plt.figure(figsize=(25,5))

tesla_investments = investments_dataset[investments_dataset.Ticker == 'TSLA']
grouped = tesla_investments.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Investments news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2014-11-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Investments)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.6935708202762231
# Spearman 0.6262830558861325
# Kendall's tau 0.3955955433459643
# DTW 3.5105500344318328

# %%
plt.figure(figsize=(25,5))

tesla_ipo = ipo_dataset[ipo_dataset.Ticker == 'TSLA']
grouped = tesla_ipo.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive IPO news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2013-06-01", end='2019-07-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (IPO)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('ipo_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson nan
# Spearman nan
# Kendall's tau nan
# DTW 6.820131400419921

# %%
plt.figure(figsize=(25,5))

tesla_legal = legal_dataset[legal_dataset.Ticker == 'TSLA']
grouped = tesla_legal.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Legal | Regulation news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2014-03-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Legal | Regulation)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('legal_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.8885707570331792
# Spearman 0.8658416211989367
# Kendall's tau 0.6571275276527292
# DTW 4.924559083210344

# %%
plt.figure(figsize=(25,5))

tesla_macro = macro_dataset[macro_dataset.Ticker == 'TSLA']
grouped = tesla_macro.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Macro news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2014-04-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Macro)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.851317567225775
# Spearman 0.7813938030784723
# Kendall's tau 0.5974726656303225
# DTW 2.419465331678393

# %%
plt.figure(figsize=(25,5))

tesla_markets = markets_dataset[markets_dataset.Ticker == 'TSLA']
grouped = tesla_markets.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Markets news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2012-11-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Markets)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.23258402537652592
# Spearman 0.7142779033316322
# Kendall's tau 0.6327185244587009
# DTW 3.4373187332428277

# %%
plt.figure(figsize=(25,5))

tesla_personnel_change = personnel_change_dataset[personnel_change_dataset.Ticker == 'TSLA']
grouped = tesla_personnel_change.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Personnel Change news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2015-03-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Personnel Change)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson -0.375455311589252
# Spearman -0.45256882419931305
# Kendall's tau -0.3603394192072481
# DTW 5.707361874281459

# %%
plt.figure(figsize=(25,5))

tesla_politics = politics_dataset[politics_dataset.Ticker == 'TSLA']
grouped = tesla_politics.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Politics news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2012-06-01", end='2019-12-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Politics)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.7814743401522399
# Spearman 0.9061332708662732
# Kendall's tau 0.7307069174786173
# DTW 1.0667384282195262

# %%
plt.figure(figsize=(30,10))

tesla_product_news = product_news_dataset[product_news_dataset.Ticker == 'TSLA']
grouped = tesla_product_news.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Company | Product news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2013-04-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Company | Product news)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('product_news_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson -0.24362065262057592
# Spearman 0.49081143442479885
# Kendall's tau 0.45535311463386163
# DTW 3.4595496591774575

# %%
plt.figure(figsize=(30,10))

tesla_stock_commentary = stock_commentary_dataset[stock_commentary_dataset.Ticker == 'TSLA']
grouped = tesla_stock_commentary.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]


import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla historical stock prices and monthly positive Stock Commentary news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2012-12-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Stock Commentary)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('stock_commentary_graph.png')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.933405740001701
# Spearman 0.9302875179392046
# Kendall's tau 0.775099660700254
# DTW 0.6496275846256682

# %%
plt.figure(figsize=(30,10))

tesla_stock_movement = stock_movement_dataset[stock_movement_dataset.Ticker == 'TSLA']
grouped = tesla_stock_movement.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly mean of Tesla historical stock prices')
plt.xlabel('Date')
plt.ylabel('Stock prices')
history_dataset = tesla_history.history(start="2012-10-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Positive news ratio')
plt.plot(dates, mean_prices, label = 'Prices')
plt.title('Monthly Tesla stock prices and Stock Movement positive news ratio', fontsize = 25)
plt.xlabel('Date', fontsize = 25)
plt.ylabel('Positive news ratio / Prices', fontsize = 25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.savefig('tesla_stock_commentary_prices_sentiments.pdf')

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.9378571971955377
# Spearman 0.9727732806546167
# Kendall's tau 0.8603602496101916
# DTW 0.4789228456669674

# %%
plt.figure(figsize=(30,10))

tesla_treasuries = treasuries_dataset[treasuries_dataset.Ticker == 'TSLA']
grouped = tesla_treasuries.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
tesla_history = yahooFinance.Ticker("TSLA")
plt.title('Monthly Tesla stock prices and Treasuries positive news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = tesla_history.history(start="2016-06-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Treasuries)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
print('Pearson', sp.pearsonr(sentiments, mean_prices)[0])
print('Spearman', sp.spearmanr(sentiments, mean_prices)[0])
print('Kendall\'s tau', sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print('DTW', dtw.distance(sentiments, mean_prices))
# Out:
# Pearson 0.7216015954304409
# Spearman 0.6591156023053814
# Kendall's tau 0.4344058173776677
# DTW 3.1411777415213136
