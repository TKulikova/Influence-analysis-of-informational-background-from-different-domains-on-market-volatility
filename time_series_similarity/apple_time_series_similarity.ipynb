# %%
import warnings
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")
import pandas as pd
pd.options.display.max_colwidth = 100
pd.options.display.max_rows = 2000
plt.style.use('seaborn-whitegrid')

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd 
analyst_update_dataset = pd.read_csv("gdrive/My Drive/analyst_update_dataset.csv", sep=',')

# %%
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
analyst_update_dataset = analyst_update_dataset.replace(replaces)
analyst_update_dataset['Release date']  = pd.to_datetime(pd.to_datetime(analyst_update_dataset['Release date']).dt.date)

# %%
general_news_dataset = pd.read_csv("gdrive/My Drive/general_news_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
general_news_dataset = general_news_dataset.replace(replaces)
general_news_dataset['Release date']  = pd.to_datetime(pd.to_datetime(general_news_dataset['Release date']).dt.date)

# %%
central_banks_dataset = pd.read_csv("gdrive/My Drive/central_banks_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
central_banks_dataset = central_banks_dataset.replace(replaces)
central_banks_dataset['Release date']  = pd.to_datetime(pd.to_datetime(central_banks_dataset['Release date']).dt.date)

# %%
currencies_dataset = pd.read_csv("gdrive/My Drive/currencies_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
currencies_dataset = currencies_dataset.replace(replaces)
currencies_dataset['Release date']  = pd.to_datetime(pd.to_datetime(currencies_dataset['Release date']).dt.date)

# %%
dividend_dataset = pd.read_csv("gdrive/My Drive/dividend_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
dividend_dataset = dividend_dataset.replace(replaces)
dividend_dataset['Release date']  = pd.to_datetime(pd.to_datetime(dividend_dataset['Release date']).dt.date)

# %%
earnings_dataset = pd.read_csv("gdrive/My Drive/earnings_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
earnings_dataset = earnings_dataset.replace(replaces)
earnings_dataset['Release date']  = pd.to_datetime(pd.to_datetime(earnings_dataset['Release date']).dt.date)

# %%
energy_oil_dataset = pd.read_csv("gdrive/My Drive/energy_oil_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
energy_oil_dataset = energy_oil_dataset.replace(replaces)
energy_oil_dataset['Release date']  = pd.to_datetime(pd.to_datetime(energy_oil_dataset['Release date']).dt.date)

# %%
financials_dataset = pd.read_csv("gdrive/My Drive/financials_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
financials_dataset = financials_dataset.replace(replaces)
financials_dataset['Release date']  = pd.to_datetime(pd.to_datetime(financials_dataset['Release date']).dt.date)

# %%
gold_metals_dataset = pd.read_csv("gdrive/My Drive/gold_metals_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
gold_metals_dataset = gold_metals_dataset.replace(replaces)
gold_metals_dataset['Release date']  = pd.to_datetime(pd.to_datetime(gold_metals_dataset['Release date']).dt.date)

# %%
investments_dataset = pd.read_csv("gdrive/My Drive/investments_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
investments_dataset = investments_dataset.replace(replaces)
investments_dataset['Release date']  = pd.to_datetime(pd.to_datetime(investments_dataset['Release date']).dt.date)

# %%
ipo_dataset = pd.read_csv("gdrive/My Drive/ipo_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
ipo_dataset = ipo_dataset.replace(replaces)
ipo_dataset['Release date']  = pd.to_datetime(pd.to_datetime(ipo_dataset['Release date']).dt.date)

# %%
legal_dataset = pd.read_csv("gdrive/My Drive/legal_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
legal_dataset = legal_dataset.replace(replaces)
legal_dataset['Release date']  = pd.to_datetime(pd.to_datetime(legal_dataset['Release date']).dt.date)

# %%
macro_dataset = pd.read_csv("gdrive/My Drive/macro_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
macro_dataset = macro_dataset.replace(replaces)
macro_dataset['Release date']  = pd.to_datetime(pd.to_datetime(macro_dataset['Release date']).dt.date)

# %%
markets_dataset = pd.read_csv("gdrive/My Drive/markets_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
markets_dataset = markets_dataset.replace(replaces)
markets_dataset['Release date']  = pd.to_datetime(pd.to_datetime(markets_dataset['Release date']).dt.date)

# %%
personnel_change_dataset = pd.read_csv("gdrive/My Drive/personnel_change_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
personnel_change_dataset = personnel_change_dataset.replace(replaces)
personnel_change_dataset['Release date']  = pd.to_datetime(pd.to_datetime(personnel_change_dataset['Release date']).dt.date)

# %%
politics_dataset = pd.read_csv("gdrive/My Drive/politics_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
politics_dataset = politics_dataset.replace(replaces)
politics_dataset['Release date']  = pd.to_datetime(pd.to_datetime(politics_dataset['Release date']).dt.date)

# %%
product_news_dataset = pd.read_csv("gdrive/My Drive/product_news_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
product_news_dataset = product_news_dataset.replace(replaces)
product_news_dataset['Release date']  = pd.to_datetime(pd.to_datetime(product_news_dataset['Release date']).dt.date)

# %%
stock_commentary_dataset = pd.read_csv("gdrive/My Drive/stock_commentary_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
stock_commentary_dataset = stock_commentary_dataset.replace(replaces)
stock_commentary_dataset['Release date']  = pd.to_datetime(pd.to_datetime(stock_commentary_dataset['Release date']).dt.date)

# %%
stock_movement_dataset = pd.read_csv("gdrive/My Drive/stock_movement_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
stock_movement_dataset = stock_movement_dataset.replace(replaces)
stock_movement_dataset['Release date']  = pd.to_datetime(pd.to_datetime(stock_movement_dataset['Release date']).dt.date)

# %%
treasuries_dataset = pd.read_csv("gdrive/My Drive/treasuries_dataset.csv", sep=',')
replaces = {"Sentiment":  {"Negative": 1, "Neutral": 2, "Positive" : 3}}
treasuries_dataset = treasuries_dataset.replace(replaces)
treasuries_dataset['Release date']  = pd.to_datetime(pd.to_datetime(treasuries_dataset['Release date']).dt.date)

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/dist-packages (0.2.14)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from yfinance) (40.0.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
# !pip install dtaidistance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dtaidistance
#   Downloading dtaidistance-2.3.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from dtaidistance) (1.22.4)
# Installing collected packages: dtaidistance
# Successfully installed dtaidistance-2.3.10

# %%
def relation_count(series):
  if 3 not in series.value_counts().index.tolist():
    pos_count = 0
  else:
    pos_count = series.value_counts()[3]
  if 2 not in series.value_counts().index.tolist():
    neutral_count = 0
  else:
    neutral_count = series.value_counts()[2]
  if series.shape[0] == 0:
    return 0
  if series.shape[0] == neutral_count:
    return 0
  return pos_count/(series.shape[0] - neutral_count)

# %%
from matplotlib import style
from scipy.signal import savgol_filter
plt.figure(figsize=(25,5))

apple_analyst_update = analyst_update_dataset[analyst_update_dataset.Ticker == 'AAPL']
apple_analyst_update.dtypes
grouped = apple_analyst_update.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(200.5).mean()
heights = np.array(heights)
sentiments = heights[0:]
plt.title('Yearly overall sentiments of financial news about Apple, related to \'Analyst Update\' topic')


import yfinance as yahooFinance

apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Analyst Update news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-09-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
dates = list(grouped_history.groups.keys())
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
plt.plot(datetimes, sentiments, label='Sentiments (Analyst Update group)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()

# %%
from dtaidistance import dtw
import scipy.stats as sp

print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.9009296988958931
# 0.9614811670764589
# 0.8704321495037672
# 1.1212994022870941

# %%
plt.figure(figsize=(25,5))

apple_general_news = general_news_dataset[general_news_dataset.Ticker == 'AAPL']
grouped = apple_general_news.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(100.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive General news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (General news | Opinion group)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-07-31 00:00:00', freq='M'), Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq=' ...

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.3926040681301559
# 0.5411966204877721
# 0.44428209345307756
# 1.336469083930821

# %%
plt.figure(figsize=(25,5))

apple_central_banks = central_banks_dataset[central_banks_dataset.Ticker == 'AAPL']
grouped = apple_central_banks.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Fed | Central banks news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-10-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Fed | Central banks)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.9007293187422118
# 0.9191779552345547
# 0.7489084200550639
# 1.4975360212532676

# %%
plt.figure(figsize=(25,5))

apple_currencies = currencies_dataset[currencies_dataset.Ticker == 'AAPL']
grouped = apple_currencies.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Currencies news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-11-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Currencies)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# -0.0014290204926499018
# 0.2673507326674928
# 0.20395616145415663
# 3.367864575959237

# %%
plt.figure(figsize=(25,5))

apple_dividend = dividend_dataset[dividend_dataset.Ticker == 'AAPL']
grouped = apple_dividend.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Dividend news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = apple_history.history(start="2012-09-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Dividend)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.9325871154331318
# 0.9151530079023491
# 0.7550963083666148
# 2.767927249329532

# %%
plt.figure(figsize=(25,5))

apple_earnings = earnings_dataset[earnings_dataset.Ticker == 'AAPL']
grouped = apple_earnings.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Earnings news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Earnings)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('earnings_graph.png')
# Out:
# [Timestamp('2012-07-31 00:00:00', freq='M'), Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq=' ...

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.9319137885596265
# 0.9392419175027872
# 0.8319902319902319
# 0.698758201632326

# %%
plt.figure(figsize=(25,5))

apple_energy_oil = energy_oil_dataset[energy_oil_dataset.Ticker == 'AAPL']
grouped = apple_energy_oil.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Energy | Oil news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-12-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Energy | Oil)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.8032236528279129
# 0.7791593943110524
# 0.6519835841313268
# 1.4109646471369364

# %%
plt.figure(figsize=(25,5))
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

apple_financials = financials_dataset[financials_dataset.Ticker == 'AAPL']
grouped = apple_financials.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Financials news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-08-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Financials)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('financials_graph.png')
# Out:
# [Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.8245542491902046
# 0.9211352926602295
# 0.7809894921254361
# 1.2089228229822013

# %%
plt.figure(figsize=(25,5))

apple_gold_metals = gold_metals_dataset[gold_metals_dataset.Ticker == 'AAPL']
grouped = apple_gold_metals.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
heights = savgol_filter(heights, 49, 2)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Gold | Metals | Materials news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-08-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Gold | Metals | Materials)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.8833227804416031
# 0.9537885335638144
# 0.8801498127340823
# 1.915353018573014

# %%
plt.figure(figsize=(25,5))

apple_investments = investments_dataset[investments_dataset.Ticker == 'AAPL']
grouped = apple_investments.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Investments news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = apple_history.history(start="2012-09-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Positive news ratio')
plt.plot(dates, mean_prices, label = 'Prices')
plt.title('Monthly Apple stock prices and monthly Investments positive news ratio', fontsize = 25)
plt.xlabel('Date', fontsize = 25)
plt.ylabel('Positive news ratio / Prices', fontsize = 25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.savefig('apple_investments_prices_sentiments.pdf')
# Out:
# [Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.9551290704655755
# 0.9532140707158502
# 0.8244530655234094
# 1.8702317137939555

# %%
plt.figure(figsize=(25,5))

apple_ipo = ipo_dataset[ipo_dataset.Ticker == 'AAPL']
grouped = apple_ipo.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive IPO news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2014-03-01", end='2019-12-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (IPO)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('ipo_graph.png')
# Out:
# [Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# -0.0912785447800567
# 0.33272679555594437
# 0.22732919254658387
# 4.8402375197513905

# %%
plt.figure(figsize=(25,5))

apple_legal = legal_dataset[legal_dataset.Ticker == 'AAPL']
grouped = apple_legal.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Legal | Regulation news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2013-08-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Legal | Regulation)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('legal_graph.png')
# Out:
# [Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.05620325306996416
# -0.1940230798887586
# -0.24724259162226153
# 2.1165405434942133

# %%
plt.figure(figsize=(25,5))

apple_macro = macro_dataset[macro_dataset.Ticker == 'AAPL']
grouped = apple_macro.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Macro news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-11-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Macro)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.8730684335713571
# 0.9198075380914194
# 0.7588879978615344
# 0.7704417021000546

# %%
plt.figure(figsize=(25,5))

apple_markets = markets_dataset[markets_dataset.Ticker == 'AAPL']
grouped = apple_markets.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Markets news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Markets)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-07-31 00:00:00', freq='M'), Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq=' ...

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# -0.10281267947979274
# -0.5168816690555822
# -0.33724053724053726
# 1.6464826767453145

# %%
plt.figure(figsize=(25,5))

apple_personnel_change = personnel_change_dataset[personnel_change_dataset.Ticker == 'AAPL']
grouped = apple_personnel_change.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Personnel Change news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2014-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Personnel Change)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.6462742488535764
# 0.6538534399254139
# 0.43351669043986346
# 2.52905463490427

# %%
plt.figure(figsize=(25,5))

apple_politics = politics_dataset[politics_dataset.Ticker == 'AAPL']
grouped = apple_politics.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Politics news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-11-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Politics)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.8634702048886334
# 0.9103988428322229
# 0.725615970774228
# 2.021562374650475

# %%
plt.figure(figsize=(30,10))

apple_product_news = product_news_dataset[product_news_dataset.Ticker == 'AAPL']
grouped = apple_product_news.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Product news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = apple_history.history(start="2012-08-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Company | Product news)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('product_news_graph.png')
# Out:
# [Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.5559087621684597
# 0.7244927357286908
# 0.597003745318352
# 0.707035484679774

# %%
plt.figure(figsize=(30,10))

apple_stock_commentary = stock_commentary_dataset[stock_commentary_dataset.Ticker == 'AAPL']
grouped = apple_stock_commentary.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Stock Commentary news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-07-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Stock Commentary)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
plt.savefig('stock_commentary_graph.png')
# Out:
# [Timestamp('2012-07-31 00:00:00', freq='M'), Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq=' ...

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.7490456726758743
# 0.7965281095715878
# 0.6683760683760683
# 1.036441004648713

# %%
plt.figure(figsize=(30,10))

apple_stock_movement = stock_movement_dataset[stock_movement_dataset.Ticker == 'AAPL']
grouped = apple_stock_movement.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Stock Movement news ratio')
plt.xlabel('Date')
history_dataset = apple_history.history(start="2012-08-01", end='2020-01-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Stock Movement)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M'), Timestamp('2020-01-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.6241527840145704
# 0.7832324978392393
# 0.6249687890137328
# 1.1250869644322476

# %%
plt.figure(figsize=(30,10))

apple_treasuries = treasuries_dataset[treasuries_dataset.Ticker == 'AAPL']
grouped = apple_treasuries.resample('M', on='Release date')
keys = list(grouped.groups.keys())
datetimes = keys[0:]
print(datetimes)
heights = grouped.agg({ 'Sentiment': [relation_count]})['Sentiment']['relation_count'].ewm(30.5).mean()
heights = np.array(heights)
sentiments = heights[0:]

import yfinance as yahooFinance
plt.figure(figsize=(25, 5))
apple_history = yahooFinance.Ticker("AAPL")
plt.title('Monthly Apple historical stock prices and monthly positive Treasuries news ratio')
plt.xlabel('Date')
plt.ylabel('Historical stock prices')
history_dataset = apple_history.history(start="2012-08-01", end='2019-12-31')
history_dataset.reset_index(inplace=True)
grouped_history = history_dataset.resample('M', on='Date')
mean_prices = grouped_history.agg({ 'Close': ['mean']})['Close']['mean'].ewm(30.5).mean()
mean_prices = mean_prices / np.max(mean_prices)
sentiments = sentiments / np.max(sentiments)
dates = list(grouped_history.groups.keys())
plt.plot(datetimes, sentiments, label='Sentiments (Treasuries)')
plt.plot(dates, mean_prices, label = 'Prices')
plt.xlabel('Date')
plt.legend()
# Out:
# [Timestamp('2012-08-31 00:00:00', freq='M'), Timestamp('2012-09-30 00:00:00', freq='M'), Timestamp('2012-10-31 00:00:00', freq='M'), Timestamp('2012-11-30 00:00:00', freq='M'), Timestamp('2012-12-31 00:00:00', freq='M'), Timestamp('2013-01-31 00:00:00', freq='M'), Timestamp('2013-02-28 00:00:00', freq='M'), Timestamp('2013-03-31 00:00:00', freq='M'), Timestamp('2013-04-30 00:00:00', freq='M'), Timestamp('2013-05-31 00:00:00', freq='M'), Timestamp('2013-06-30 00:00:00', freq='M'), Timestamp('2013-07-31 00:00:00', freq='M'), Timestamp('2013-08-31 00:00:00', freq='M'), Timestamp('2013-09-30 00:00:00', freq='M'), Timestamp('2013-10-31 00:00:00', freq='M'), Timestamp('2013-11-30 00:00:00', freq='M'), Timestamp('2013-12-31 00:00:00', freq='M'), Timestamp('2014-01-31 00:00:00', freq='M'), Timestamp('2014-02-28 00:00:00', freq='M'), Timestamp('2014-03-31 00:00:00', freq='M'), Timestamp('2014-04-30 00:00:00', freq='M'), Timestamp('2014-05-31 00:00:00', freq='M'), Timestamp('2014-06-30 00:00:00', freq='M'), Timestamp('2014-07-31 00:00:00', freq='M'), Timestamp('2014-08-31 00:00:00', freq='M'), Timestamp('2014-09-30 00:00:00', freq='M'), Timestamp('2014-10-31 00:00:00', freq='M'), Timestamp('2014-11-30 00:00:00', freq='M'), Timestamp('2014-12-31 00:00:00', freq='M'), Timestamp('2015-01-31 00:00:00', freq='M'), Timestamp('2015-02-28 00:00:00', freq='M'), Timestamp('2015-03-31 00:00:00', freq='M'), Timestamp('2015-04-30 00:00:00', freq='M'), Timestamp('2015-05-31 00:00:00', freq='M'), Timestamp('2015-06-30 00:00:00', freq='M'), Timestamp('2015-07-31 00:00:00', freq='M'), Timestamp('2015-08-31 00:00:00', freq='M'), Timestamp('2015-09-30 00:00:00', freq='M'), Timestamp('2015-10-31 00:00:00', freq='M'), Timestamp('2015-11-30 00:00:00', freq='M'), Timestamp('2015-12-31 00:00:00', freq='M'), Timestamp('2016-01-31 00:00:00', freq='M'), Timestamp('2016-02-29 00:00:00', freq='M'), Timestamp('2016-03-31 00:00:00', freq='M'), Timestamp('2016-04-30 00:00:00', freq='M'), Timestamp('2016-05-31 00:00:00', freq='M'), Timestamp('2016-06-30 00:00:00', freq='M'), Timestamp('2016-07-31 00:00:00', freq='M'), Timestamp('2016-08-31 00:00:00', freq='M'), Timestamp('2016-09-30 00:00:00', freq='M'), Timestamp('2016-10-31 00:00:00', freq='M'), Timestamp('2016-11-30 00:00:00', freq='M'), Timestamp('2016-12-31 00:00:00', freq='M'), Timestamp('2017-01-31 00:00:00', freq='M'), Timestamp('2017-02-28 00:00:00', freq='M'), Timestamp('2017-03-31 00:00:00', freq='M'), Timestamp('2017-04-30 00:00:00', freq='M'), Timestamp('2017-05-31 00:00:00', freq='M'), Timestamp('2017-06-30 00:00:00', freq='M'), Timestamp('2017-07-31 00:00:00', freq='M'), Timestamp('2017-08-31 00:00:00', freq='M'), Timestamp('2017-09-30 00:00:00', freq='M'), Timestamp('2017-10-31 00:00:00', freq='M'), Timestamp('2017-11-30 00:00:00', freq='M'), Timestamp('2017-12-31 00:00:00', freq='M'), Timestamp('2018-01-31 00:00:00', freq='M'), Timestamp('2018-02-28 00:00:00', freq='M'), Timestamp('2018-03-31 00:00:00', freq='M'), Timestamp('2018-04-30 00:00:00', freq='M'), Timestamp('2018-05-31 00:00:00', freq='M'), Timestamp('2018-06-30 00:00:00', freq='M'), Timestamp('2018-07-31 00:00:00', freq='M'), Timestamp('2018-08-31 00:00:00', freq='M'), Timestamp('2018-09-30 00:00:00', freq='M'), Timestamp('2018-10-31 00:00:00', freq='M'), Timestamp('2018-11-30 00:00:00', freq='M'), Timestamp('2018-12-31 00:00:00', freq='M'), Timestamp('2019-01-31 00:00:00', freq='M'), Timestamp('2019-02-28 00:00:00', freq='M'), Timestamp('2019-03-31 00:00:00', freq='M'), Timestamp('2019-04-30 00:00:00', freq='M'), Timestamp('2019-05-31 00:00:00', freq='M'), Timestamp('2019-06-30 00:00:00', freq='M'), Timestamp('2019-07-31 00:00:00', freq='M'), Timestamp('2019-08-31 00:00:00', freq='M'), Timestamp('2019-09-30 00:00:00', freq='M'), Timestamp('2019-10-31 00:00:00', freq='M'), Timestamp('2019-11-30 00:00:00', freq='M'), Timestamp('2019-12-31 00:00:00', freq='M')]

# %%
import scipy.stats as sp
print(sp.pearsonr(sentiments, mean_prices)[0])
print(sp.spearmanr(sentiments, mean_prices)[0])
print(sp.kendalltau(sentiments, mean_prices)[0])
mean_prices = mean_prices / np.max(mean_prices)
print(dtw.distance(sentiments, mean_prices))
# Out:
# 0.957967951736046
# 0.955580639968121
# 0.8084831672543519
# 2.608613184653155
